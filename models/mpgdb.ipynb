# %%
import pandas as pd
import numpy as np
from sklearn import pipeline,preprocessing,metrics,model_selection,ensemble
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import OneHotEncoder
import statsmodels.api as sm

# %%
data=pd.read_excel(r'G:\DBA\MOD_2_core analytics\django\djangoTut\mpgWebApp\models\mileage_new.xls')

# %%
data
# Out:
#       mpg  cyl   disp   hp    wt   acc  modyr  origin  \
# 0    18.0    8  307.0  130  3504  12.0     70       1
# 1    15.0    8  350.0  165  3693  11.5     70       1
# 2    18.0    8  318.0  150  3436  11.0     70       1
# 3    16.0    8  304.0  150  3433  12.0     70       1
# 4    17.0    8  302.0  140  3449  10.5     70       1
# ..    ...  ...    ...  ...   ...   ...    ...     ...
# 387  27.0    4  140.0   86  2790  15.6     82       1
# 388  44.0    4   97.0   52  2130  24.6     82       2
# 389  32.0    4  135.0   84  2295  11.6     82       1
# 390  28.0    4  120.0   79  2625  18.6     82       1
# 391  31.0    4  119.0   82  2720  19.4     82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# 389              dodge rampage
# 390                ford ranger
# 391                 chevy s-10
#
# [392 rows x 9 columns]

# %%
mapper = DataFrameMapper([
                        (['cyl','disp','wt','acc','modyr'],preprocessing.StandardScaler()),
                        (['origin'],preprocessing.OneHotEncoder(handle_unknown = 'ignore'))
                        ])

# %%
# target and features
y=data['mpg']
X=data.iloc[:,:-1] 

# Fit a regression model
res = sm.OLS(y, X).fit()
print(res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    mpg   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          6.836e+30
# Date:                Sat, 04 Sep 2021   Prob (F-statistic):                        0.00
# Time:                        08:54:54   Log-Likelihood:                          11344.
# No. Observations:                 392   AIC:                                 -2.267e+04
# Df Residuals:                     384   BIC:                                 -2.264e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mpg            1.0000   9.97e-16      1e+15      0.000       1.000       1.000
# cyl         1.665e-15   6.36e-15      0.262      0.794   -1.08e-14    1.42e-14
# disp       -1.336e-16   1.51e-16     -0.887      0.376    -4.3e-16    1.63e-16
# hp          1.769e-16   2.49e-16      0.711      0.478   -3.13e-16    6.66e-16
# wt         -2.038e-17   1.41e-17     -1.447      0.149   -4.81e-17    7.32e-18
# acc        -6.661e-16   1.77e-15     -0.377      0.707   -4.14e-15    2.81e-15
# modyr      -1.388e-17    7.5e-16     -0.019      0.985   -1.49e-15    1.46e-15
# origin     -5.551e-16   5.65e-15     -0.098      0.922   -1.17e-14    1.05e-14
# ==============================================================================
# Omnibus:                      104.802   Durbin-Watson:                   0.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.373
# Skew:                           0.402   Prob(JB):                     6.90e-07
# Kurtosis:                       1.956   Cond. No.                     6.10e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 6.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn.linear_model import LinearRegression
pipeline_obj=pipeline.Pipeline([
    ('mapper',mapper),
    ("model",LinearRegression())
])

# %%
pipeline_obj.fit(X,y)
# Out:
# Pipeline(steps=[('mapper',
#                  DataFrameMapper(drop_cols=[],
#                                  features=[(['cyl', 'disp', 'wt', 'acc',
#                                              'modyr'],
#                                             StandardScaler()),
#                                            (['origin'],
#                                             OneHotEncoder(handle_unknown='ignore'))])),
#                 ('model', LinearRegression())])

# %%
pipeline_obj.predict(X)
# Out:
# array([14.69259797, 14.17438777, 15.2464884 , 15.1334358 , 14.73855676,
#        10.99529654, 11.26831869, 11.19265642, 10.94506371, 13.42134463,
#        15.55030739, 14.00202331, 14.42239846, 20.44665907, 23.56338615,
#        18.59950227, 19.03916216, 20.46690002, 24.86494429, 27.75409211,
#        21.60891488, 22.78446495, 23.59047649, 24.15005907, 19.85347794,
#         8.24070197,  8.98356284,  8.93256138,  6.95288767, 25.65638018,
#        23.08622631, 25.21708145, 21.11790795, 15.65756693, 16.9629719 ,
#        17.15456494, 16.87602413, 11.38405291, 10.54445959, 12.03468382,
#        11.67367919,  6.70341304,  8.62316183,  5.82732272, 19.41602681,
#        22.62289217, 17.21670065, 18.15164909, 22.78121149, 25.86354223,
#        26.31211938, 25.76707586, 28.36189697, 29.35868663, 28.31326888,
#        25.04806482, 25.89307059, 24.20404137, 26.84243414, 23.49411311,
#        23.92899642, 11.71424631, 11.97626757, 12.26815463, 12.92373561,
#        14.94056935, 10.66569522, 10.33570473, 10.66212249, 11.7934992 ,
#        24.73984672, 13.53901102, 12.37956317, 11.20291172, 12.75950991,
#        21.09194025, 24.64496382, 21.5423794 , 26.40504741, 22.64998088,
#        25.72556728, 24.26255914, 23.62574851, 26.97983744, 13.89996298,
#        15.73200524, 14.69471928, 13.54319411, 15.44040215,  9.27327993,
#        12.20711642, 12.05469852, 12.49536472, 10.96426513,  9.7464253 ,
#        15.77055377, 19.65654901, 19.30666691, 20.97262212, 20.8909936 ,
#        20.54977626, 29.39214042,  8.74406819,  9.15045252, 10.17869403,
#        10.98885862, 21.920034  , 26.90000773, 24.33522126, 26.02240856,
#        26.99306651, 24.4435053 , 22.39339852, 26.30024638, 14.02769167,
#        13.12805429, 29.13294117, 27.43740783, 24.14734514, 22.50418874,
#        17.88334948, 23.74080956, 22.63901518, 16.67469549, 20.01598161,
#        22.0762837 , 19.52696246, 29.64815489, 23.91525957, 30.60829444,
#        23.72719047, 16.36922539, 17.75405426, 16.95673403, 13.55233715,
#        10.68022705, 11.56610206, 10.3447463 , 13.01053912, 27.57767014,
#        28.83580687, 26.66275718, 31.32215628, 29.35603938, 25.23763169,
#        28.03781124, 27.36503718, 26.04584863, 26.56912188, 28.65303851,
#        20.14490225, 19.28601553, 20.2754591 , 21.98041845, 12.26261132,
#        13.22975182, 12.22617048, 11.63112007, 16.5059619 , 16.57687599,
#        18.0096485 , 16.92657659, 21.70790255, 19.95259806, 20.92198211,
#        28.77054132, 23.83031064, 22.77547109, 24.40317961, 25.38038401,
#        28.17277283, 26.73805295, 20.75878179, 29.80331453, 20.8275178 ,
#        25.11602436, 23.67387464, 23.38109546, 25.16583986, 31.55204513,
#        27.45138508, 29.59515926, 24.76208387, 26.57659186, 29.15267133,
#        14.51351287, 14.96383102, 16.43143004, 15.44730584, 21.06057326,
#        20.59027632, 22.45501122, 22.60879659, 28.58286859, 27.92443983,
#        30.62666444, 32.327524  , 18.46144047, 20.05925754, 18.7895023 ,
#        22.42017285, 31.24923593, 30.7540067 , 29.73934187, 24.604315  ,
#        23.09827029, 16.76975463, 23.02614405, 24.45965034, 18.42597976,
#        14.14376681, 16.43402226, 17.21780543, 18.21017782, 31.66743283,
#        27.88779547, 32.68403517, 27.20149892, 31.83285029, 17.60233655,
#        16.41754199, 16.2217679 , 14.977468  , 20.499857  , 20.85488673,
#        19.40189317, 20.87925909, 16.96068024, 16.34915187, 16.39112333,
#        15.65848631, 31.59163866, 24.76784237, 30.03743973, 24.39855784,
#        28.7039205 , 28.35808846, 31.73710428, 29.75380103, 25.69762423,
#        27.14083129, 26.1395075 , 33.03378816, 30.86157974, 32.60837151,
#        32.02450758, 33.71534548, 21.58222916, 19.80731427, 20.57843448,
#        21.23276964, 23.11889157, 24.0841706 , 25.37452703, 21.53275167,
#        23.24083553, 21.79011722, 23.48269967, 20.42385955, 22.03236501,
#        21.73416897, 20.94590647, 22.9131763 , 17.43896609, 28.67758335,
#        28.87402819, 30.48387877, 27.97319567, 29.28909198, 25.74046529,
#        24.99854602, 29.77070876, 26.56714554, 24.23452213, 27.01129301,
#        22.66964601, 31.92415163, 31.51704206, 23.47569025, 25.08117379,
#        25.2628196 , 23.80155941, 22.72516818, 19.93180318, 20.36572648,
#        19.73041152, 20.24376673, 17.10679154, 19.20343084, 20.7377862 ,
#        19.99388075, 33.03321691, 32.96852238, 30.83697121, 26.05805781,
#        24.15321781, 20.76989445, 26.87175433, 23.05250266, 28.77007156,
#        29.39614267, 33.26648745, 31.73221539, 26.84743683, 26.21624718,
#        25.72647533, 27.2095889 , 32.57126215, 34.44706381, 30.34924636,
#        33.63921671, 27.66188947, 26.32383234, 25.93012939, 23.70268449,
#        32.41356995, 29.59283932, 30.81729919, 31.16375244, 32.16396701,
#        33.23283238, 26.56604371, 33.41927989, 33.93897012, 32.48410075,
#        27.72683685, 26.86368574, 34.52853306, 33.23135798, 34.59977701,
#        27.36500079, 30.27312026, 30.61274766, 32.25279861, 29.3238264 ,
#        28.74249799, 28.6347665 , 27.08407511, 29.62211412, 36.23683636,
#        32.77090118, 36.11568734, 34.55856291, 35.20059497, 34.41726939,
#        34.71305801, 30.51777195, 31.7845842 , 30.12547683, 33.10345063,
#        33.19703529, 32.60755181, 30.63889136, 31.0764596 , 27.4686761 ,
#        27.04644433, 28.41888119, 27.9356243 , 23.91606355, 23.84988512,
#        25.99179576, 23.56295593, 29.4386878 , 29.03075635, 30.67354368,
#        29.10903058, 29.91477197, 29.07964222, 27.67091513, 35.56058169,
#        35.5717066 , 35.86624664, 31.91593727, 32.18386414, 34.6321473 ,
#        34.03990838, 34.16002873, 35.48684455, 35.59854363, 35.46544753,
#        27.08869801, 28.38820145, 29.69052075, 28.66866819, 31.45675299,
#        30.5359476 , 27.4422949 , 28.07546192, 35.8122289 , 30.84475232,
#        29.30514596, 28.73768477])

# %%
import joblib

# %%
joblib.dump(pipeline_obj,'RFModelforMPG3.pkl')
# Out:
# ['RFModelforMPG3.pkl']

# %%
modelReload=joblib.load('RFModelforMPG3.pkl')

# %%
modelReload.predict(X)
# Out:
# array([14.69259797, 14.17438777, 15.2464884 , 15.1334358 , 14.73855676,
#        10.99529654, 11.26831869, 11.19265642, 10.94506371, 13.42134463,
#        15.55030739, 14.00202331, 14.42239846, 20.44665907, 23.56338615,
#        18.59950227, 19.03916216, 20.46690002, 24.86494429, 27.75409211,
#        21.60891488, 22.78446495, 23.59047649, 24.15005907, 19.85347794,
#         8.24070197,  8.98356284,  8.93256138,  6.95288767, 25.65638018,
#        23.08622631, 25.21708145, 21.11790795, 15.65756693, 16.9629719 ,
#        17.15456494, 16.87602413, 11.38405291, 10.54445959, 12.03468382,
#        11.67367919,  6.70341304,  8.62316183,  5.82732272, 19.41602681,
#        22.62289217, 17.21670065, 18.15164909, 22.78121149, 25.86354223,
#        26.31211938, 25.76707586, 28.36189697, 29.35868663, 28.31326888,
#        25.04806482, 25.89307059, 24.20404137, 26.84243414, 23.49411311,
#        23.92899642, 11.71424631, 11.97626757, 12.26815463, 12.92373561,
#        14.94056935, 10.66569522, 10.33570473, 10.66212249, 11.7934992 ,
#        24.73984672, 13.53901102, 12.37956317, 11.20291172, 12.75950991,
#        21.09194025, 24.64496382, 21.5423794 , 26.40504741, 22.64998088,
#        25.72556728, 24.26255914, 23.62574851, 26.97983744, 13.89996298,
#        15.73200524, 14.69471928, 13.54319411, 15.44040215,  9.27327993,
#        12.20711642, 12.05469852, 12.49536472, 10.96426513,  9.7464253 ,
#        15.77055377, 19.65654901, 19.30666691, 20.97262212, 20.8909936 ,
#        20.54977626, 29.39214042,  8.74406819,  9.15045252, 10.17869403,
#        10.98885862, 21.920034  , 26.90000773, 24.33522126, 26.02240856,
#        26.99306651, 24.4435053 , 22.39339852, 26.30024638, 14.02769167,
#        13.12805429, 29.13294117, 27.43740783, 24.14734514, 22.50418874,
#        17.88334948, 23.74080956, 22.63901518, 16.67469549, 20.01598161,
#        22.0762837 , 19.52696246, 29.64815489, 23.91525957, 30.60829444,
#        23.72719047, 16.36922539, 17.75405426, 16.95673403, 13.55233715,
#        10.68022705, 11.56610206, 10.3447463 , 13.01053912, 27.57767014,
#        28.83580687, 26.66275718, 31.32215628, 29.35603938, 25.23763169,
#        28.03781124, 27.36503718, 26.04584863, 26.56912188, 28.65303851,
#        20.14490225, 19.28601553, 20.2754591 , 21.98041845, 12.26261132,
#        13.22975182, 12.22617048, 11.63112007, 16.5059619 , 16.57687599,
#        18.0096485 , 16.92657659, 21.70790255, 19.95259806, 20.92198211,
#        28.77054132, 23.83031064, 22.77547109, 24.40317961, 25.38038401,
#        28.17277283, 26.73805295, 20.75878179, 29.80331453, 20.8275178 ,
#        25.11602436, 23.67387464, 23.38109546, 25.16583986, 31.55204513,
#        27.45138508, 29.59515926, 24.76208387, 26.57659186, 29.15267133,
#        14.51351287, 14.96383102, 16.43143004, 15.44730584, 21.06057326,
#        20.59027632, 22.45501122, 22.60879659, 28.58286859, 27.92443983,
#        30.62666444, 32.327524  , 18.46144047, 20.05925754, 18.7895023 ,
#        22.42017285, 31.24923593, 30.7540067 , 29.73934187, 24.604315  ,
#        23.09827029, 16.76975463, 23.02614405, 24.45965034, 18.42597976,
#        14.14376681, 16.43402226, 17.21780543, 18.21017782, 31.66743283,
#        27.88779547, 32.68403517, 27.20149892, 31.83285029, 17.60233655,
#        16.41754199, 16.2217679 , 14.977468  , 20.499857  , 20.85488673,
#        19.40189317, 20.87925909, 16.96068024, 16.34915187, 16.39112333,
#        15.65848631, 31.59163866, 24.76784237, 30.03743973, 24.39855784,
#        28.7039205 , 28.35808846, 31.73710428, 29.75380103, 25.69762423,
#        27.14083129, 26.1395075 , 33.03378816, 30.86157974, 32.60837151,
#        32.02450758, 33.71534548, 21.58222916, 19.80731427, 20.57843448,
#        21.23276964, 23.11889157, 24.0841706 , 25.37452703, 21.53275167,
#        23.24083553, 21.79011722, 23.48269967, 20.42385955, 22.03236501,
#        21.73416897, 20.94590647, 22.9131763 , 17.43896609, 28.67758335,
#        28.87402819, 30.48387877, 27.97319567, 29.28909198, 25.74046529,
#        24.99854602, 29.77070876, 26.56714554, 24.23452213, 27.01129301,
#        22.66964601, 31.92415163, 31.51704206, 23.47569025, 25.08117379,
#        25.2628196 , 23.80155941, 22.72516818, 19.93180318, 20.36572648,
#        19.73041152, 20.24376673, 17.10679154, 19.20343084, 20.7377862 ,
#        19.99388075, 33.03321691, 32.96852238, 30.83697121, 26.05805781,
#        24.15321781, 20.76989445, 26.87175433, 23.05250266, 28.77007156,
#        29.39614267, 33.26648745, 31.73221539, 26.84743683, 26.21624718,
#        25.72647533, 27.2095889 , 32.57126215, 34.44706381, 30.34924636,
#        33.63921671, 27.66188947, 26.32383234, 25.93012939, 23.70268449,
#        32.41356995, 29.59283932, 30.81729919, 31.16375244, 32.16396701,
#        33.23283238, 26.56604371, 33.41927989, 33.93897012, 32.48410075,
#        27.72683685, 26.86368574, 34.52853306, 33.23135798, 34.59977701,
#        27.36500079, 30.27312026, 30.61274766, 32.25279861, 29.3238264 ,
#        28.74249799, 28.6347665 , 27.08407511, 29.62211412, 36.23683636,
#        32.77090118, 36.11568734, 34.55856291, 35.20059497, 34.41726939,
#        34.71305801, 30.51777195, 31.7845842 , 30.12547683, 33.10345063,
#        33.19703529, 32.60755181, 30.63889136, 31.0764596 , 27.4686761 ,
#        27.04644433, 28.41888119, 27.9356243 , 23.91606355, 23.84988512,
#        25.99179576, 23.56295593, 29.4386878 , 29.03075635, 30.67354368,
#        29.10903058, 29.91477197, 29.07964222, 27.67091513, 35.56058169,
#        35.5717066 , 35.86624664, 31.91593727, 32.18386414, 34.6321473 ,
#        34.03990838, 34.16002873, 35.48684455, 35.59854363, 35.46544753,
#        27.08869801, 28.38820145, 29.69052075, 28.66866819, 31.45675299,
#        30.5359476 , 27.4422949 , 28.07546192, 35.8122289 , 30.84475232,
#        29.30514596, 28.73768477])
